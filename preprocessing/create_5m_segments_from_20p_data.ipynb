# %%
# NOTE: only use road vector patches that do not include nan values

# TODO
# 1) read road vectors from padasjoki_csv, add points if distance between two consecutive points is greater than 0.5m
# 2) find correct 20p tiles (need to create tiles before)
# 3) use def segment_point_cloud_along_road: filter with distance 10m from road vector points, check the splitting points from Padasjoki_csv_20231023,
# NOTE CHECK split_MML_Dense_ALS_file_along_road to create 5m segments.
# 4) handle to end points so that segment ends are not spherical
# 4) save the whole road patch with splitcode indices
