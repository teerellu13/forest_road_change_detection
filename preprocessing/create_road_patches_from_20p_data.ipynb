# %%
# This script is for creating road patches from 20p data that correspond to road patches of 5p data. 
# Paula's road vectors are used for this purpose. Some of these road vectors may contain NaN values.

# %%
east_min = 395000.0 # 395500.0 
east_max = 407000.0 # 400500.0 
north_min = 6783000.0 # 6783500.0 
north_max = 6795000.0 # 6788500.0 

print(east_max-east_min)
print(north_max-north_min)
# Out:
# 12000.0
# 12000.0

# %%
import os
import re
import math
import shutil
import laspy
import numpy as np

def parse_tile_coordinates(filename):
    """Extract x and y tile coordinates from the filename."""
    match = re.search(r"tile_x_(\d+)_y_(\d+)\.laz", filename)
    if match:
        x = int(match.group(1))
        y = int(match.group(2))
        return x, y
    return None

def find_n_closest_tiles(point, folder_path, n):
    """Find the four tiles whose (x, y) are closest to the given 3D point's (x, y)."""
    point_x, point_y, _ = point  # Ignore z
    distances = []

    for filename in os.listdir(folder_path):
        if filename.endswith('.laz'):
            coords = parse_tile_coordinates(filename)
            if coords:
                tile_x, tile_y = coords

                dist = math.hypot(tile_x - point_x, tile_y - point_y)
                distances.append((dist, filename))

    # Sort by distance and get the four closest files
    distances.sort()
    closest_files = [filename for _, filename in distances[:n]]

    return closest_files

# %%
folder_road_vectors = r"C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023"
folder_tiles = r"E:\ALS_DATA\NLS_20p_EVO_TILES" 
output_folder = r"E:\ALS_DATA\NLS_20p_EVO_road_patches"

for file_road_vector in os.listdir(folder_road_vectors):
    output_path = os.path.join(output_folder, f"{file_road_vector}")
    if os.path.exists(output_path):
        print(f"Output file {output_path} already exists. Skipping...")
        continue

    file_path_road_vector = os.path.join(folder_road_vectors, file_road_vector)
    road_vector = laspy.read(file_path_road_vector)
    points_road_vector = np.vstack((road_vector.x, road_vector.y, road_vector.z)).T

    east_min = 395000.0 # 395500.0 
    east_max = 407000.0 # 400500.0 
    north_min = 6783000.0 # 6783500.0 
    north_max = 6795000.0 # 6788500.0 

    if points_road_vector.shape[0] == 0:
        continue
    if points_road_vector[0,0] > east_min and points_road_vector[0,0] < east_max and points_road_vector[0,1] > north_min and points_road_vector[0,1] < north_max:
        print(f"Loaded {len(points_road_vector)} trajectory points from {file_path_road_vector}")

        # TODO check that road vector does not contain NaN values
        # TODO add points if the distance between two consecutive points is too large

        all_nearby_points = None

        for point in points_road_vector:
            #print(f"Trajectory Point: {point}")
            closest_tiles = find_n_closest_tiles(point, folder_tiles, n=4)

            for tile_name in closest_tiles:
                tile_path = os.path.join(folder_tiles, tile_name)
                tile = laspy.read(tile_path)  

                tile_points = np.vstack((tile.x, tile.y, tile.z, tile.intensity, tile.scan_angle, tile.return_number, tile.gps_time, tile.classification, tile.Amplitude, tile.Deviation, tile.Reflectance)).T

                # Compute horizontal distance to current trajectory point
                dx = tile.x - point[0]
                dy = tile.y - point[1]
                horizontal_dist = np.sqrt(dx**2 + dy**2)

                nearby_mask = horizontal_dist <= 10
                # nearby_points = tile.points[nearby_mask]
                # nearby_points = tile.points.array[nearby_mask]
                nearby_points = tile_points[nearby_mask]
                if nearby_points.size > 0:
                    if all_nearby_points is None:
                        all_nearby_points = nearby_points
                    else:
                        all_nearby_points = np.vstack([all_nearby_points, nearby_points])

                        # all_nearby_points = np.concatenate([all_nearby_points, nearby_points])

        print(f"Found {len(all_nearby_points)} nearby points.")

        # Stack all filtered points into one numpy array
        if all_nearby_points is not None:
            all_points = np.vstack(all_nearby_points)
        else:
            all_points = np.empty((0, 9))

        # if all_nearby_points is None:
        #     all_nearby_points = np.empty((0, 9))

        # 1. Remove duplicate rows (points)
        unique_points = np.unique(all_points, axis=0)

        # 2. Create a new LAS file with the unique points
        header = laspy.LasHeader(point_format=6, version="1.4")
        las = laspy.LasData(header)


        las.x = unique_points[:, 0]
        las.y = unique_points[:, 1]
        las.z = unique_points[:, 2]
        las.intensity = unique_points[:,3]
        las.scan_angle = unique_points[:,4]
        las.return_number = unique_points[:,5]
        las.gps_time = unique_points[:,6]
        las.classification = unique_points[:,7]
        las.Amplitude = unique_points[:,8]
        las.Deviation = unique_points[:,9]
        las.Reflectance = unique_points[:,10]

        output_path = os.path.join(output_folder, f"{file_road_vector}")
        las.write(output_path)

        print(f"Saved {len(unique_points)} unique points to {output_path}")
# Out:
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1059456207_2206.las
# Found 211368 nearby points.
# Saved 65025 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1059456207_2206.las
# Loaded 71 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1059692462_2202.las
# Found 1431502 nearby points.
# Saved 475758 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1059692462_2202.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1060074237_2244.las
# Found 129127 nearby points.
# Saved 41206 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1060074237_2244.las
# Loaded 61 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062609023_1679.las
# Found 883722 nearby points.
# Saved 295020 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062609023_1679.las
# Loaded 40 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062609032_1680.las
# Found 953646 nearby points.
# Saved 323517 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062609032_1680.las
# Loaded 55 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062628454_17308.las
# Found 1009802 nearby points.
# Saved 338785 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062628454_17308.las
# Loaded 54 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062628537_1529.las
# Found 192363 nearby points.
# Saved 67454 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062628537_1529.las
# Loaded 135 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062657407_17304.las
# Found 3004705 nearby points.
# Saved 973291 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062657407_17304.las
# Loaded 86 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062745668_17318.las
# Found 1688843 nearby points.
# Saved 570047 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062745668_17318.las
# Loaded 110 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062813320_1549.las
# Found 1393767 nearby points.
# Saved 468145 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062813320_1549.las
# Loaded 265 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1062875775_17342.las
# Found 4774817 nearby points.
# Saved 678444 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1062875775_17342.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1063326892_17278.las
# Found 154993 nearby points.
# Saved 58555 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1063326892_17278.las
# Loaded 144 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1065286727_1648.las
# Found 2094290 nearby points.
# Saved 694976 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1065286727_1648.las
# Loaded 131 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1067913673_17676.las
# Found 2842514 nearby points.
# Saved 397272 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1067913673_17676.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1067913682_17680.las
# Found 504163 nearby points.
# Saved 169397 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1067913682_17680.las
# Loaded 113 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1068025888_17679.las
# Found 3295603 nearby points.
# Saved 435208 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1068025888_17679.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1068026009_17691.las
# Found 332590 nearby points.
# Saved 107931 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1068026009_17691.las
# Loaded 18 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072726656_1619.las
# Found 177569 nearby points.
# Saved 65312 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072726656_1619.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072726715_2220.las
# Found 286919 nearby points.
# Saved 95441 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072726715_2220.las
# Loaded 84 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072726723_2218.las
# Found 1356731 nearby points.
# Saved 442008 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072726723_2218.las
# Loaded 3 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072765522_2212.las
# Found 34926 nearby points.
# Saved 18570 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072765522_2212.las
# Loaded 100 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072854029_17282.las
# Found 2260389 nearby points.
# Saved 749563 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072854029_17282.las
# Loaded 55 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1072854059_17316.las
# Found 771567 nearby points.
# Saved 255188 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1072854059_17316.las
# Loaded 168 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073064355_17649.las
# Found 3349120 nearby points.
# Saved 1090211 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073064355_17649.las
# Loaded 127 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073267728_1651.las
# Found 2351490 nearby points.
# Saved 773727 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073267728_1651.las
# Loaded 14 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073267734_1650.las
# Found 172000 nearby points.
# Saved 55869 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073267734_1650.las
# Loaded 428 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073267847_1673.las
# Found 6838943 nearby points.
# Saved 1173051 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073267847_1673.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073279136_1635.las
# Found 299749 nearby points.
# Saved 114313 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073279136_1635.las
# Loaded 62 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1073279145_1632.las
# Found 1972214 nearby points.
# Saved 646862 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1073279145_1632.las
# Loaded 61 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1074202628_7847.las
# Found 1156371 nearby points.
# Saved 379913 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1074202628_7847.las
# Loaded 61 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1076666785_47416.las
# Found 657959 nearby points.
# Saved 224493 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1076666785_47416.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1077366443_45451.las
# Found 18164 nearby points.
# Saved 12314 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1077366443_45451.las
# Loaded 31 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1077366479_45445.las
# Found 591496 nearby points.
# Saved 201748 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1077366479_45445.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1077366617_45474.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419324_45480.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419383_45429.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419475_997.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487225_45422.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487234_45424.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487241_45420.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487250_45423.las already exists. Skipping...
# Loaded 81 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1080695621_34830.las
# Found 1665641 nearby points.
# Saved 542226 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080695621_34830.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1081001846_47112.las already exists. Skipping...
# Loaded 208 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199190_34846.las
# Found 3841064 nearby points.
# Saved 1296969 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199190_34846.las
# Loaded 33 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199196_34852.las
# Found 739004 nearby points.
# Saved 247667 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199196_34852.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199202_34849.las
# Found 138971 nearby points.
# Saved 42509 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199202_34849.las
# Loaded 140 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199211_47738.las
# Found 2429610 nearby points.
# Saved 805174 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199211_47738.las
# Loaded 78 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199233_34829.las
# Found 1025826 nearby points.
# Saved 339205 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199233_34829.las
# Loaded 183 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199236_34840.las
# Found 3342760 nearby points.
# Saved 1107309 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199236_34840.las
# Loaded 270 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199242_34854.las
# Found 5274610 nearby points.
# Saved 1794968 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199242_34854.las
# Loaded 4 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199284_34844.las
# Found 46389 nearby points.
# Saved 23578 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199284_34844.las
# Loaded 4 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199299_34843.las
# Found 46023 nearby points.
# Saved 23193 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199299_34843.las
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199342_34831.las
# Found 99989 nearby points.
# Saved 47167 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199342_34831.las
# Loaded 4 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199348_47729.las
# Found 73214 nearby points.
# Saved 36776 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199348_47729.las
# Loaded 95 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081199358_34832.las
# Found 1470332 nearby points.
# Saved 488567 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081199358_34832.las
# Loaded 84 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081200822_34833.las
# Found 1208275 nearby points.
# Saved 409678 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081200822_34833.las
# Loaded 24 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081200828_34842.las
# Found 302786 nearby points.
# Saved 98359 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081200828_34842.las
# Loaded 39 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081200839_34804.las
# Found 524570 nearby points.
# Saved 174743 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081200839_34804.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081200908_34817.las
# Found 173862 nearby points.
# Saved 62425 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081200908_34817.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450116_34886.las
# Found 161029 nearby points.
# Saved 60501 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450116_34886.las
# Loaded 111 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450138_34853.las
# Found 2105004 nearby points.
# Saved 684438 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450138_34853.las
# Loaded 259 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450197_34872.las
# Found 3689707 nearby points.
# Saved 1240814 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450197_34872.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450259_34893.las
# Found 532460 nearby points.
# Saved 186359 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450259_34893.las
# Loaded 722 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450265_7792.las
# Found 18797183 nearby points.
# Saved 3408514 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450265_7792.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081450304_34910.las
# Found 42599 nearby points.
# Saved 29075 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081450304_34910.las
# Loaded 90 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081589854_34911.las
# Found 2070127 nearby points.
# Saved 695918 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081589854_34911.las
# Loaded 92 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1081589907_34890.las
# Found 1510156 nearby points.
# Saved 511384 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081589907_34890.las
# Loaded 128 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1082185743_34864.las
# Found 937646 nearby points.
# Saved 316866 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1082185743_34864.las
# Loaded 174 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1083742860_19153.las
# Found 526142 nearby points.
# Saved 80554 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1083742860_19153.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1083742875_19152.las already exists. Skipping...
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1084932926_9598.las
# Found 177766 nearby points.
# Saved 64757 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1084932926_9598.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1084932935_9596.las
# Found 290443 nearby points.
# Saved 103114 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1084932935_9596.las
# Loaded 77 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1084932956_670.las
# Found 1786624 nearby points.
# Saved 590530 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1084932956_670.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1085187404_9835.las already exists. Skipping...
# Loaded 8 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086064474_39816.las
# Found 102621 nearby points.
# Saved 42284 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086064474_39816.las
# Loaded 49 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086064480_39815.las
# Found 677590 nearby points.
# Saved 229306 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086064480_39815.las
# Loaded 60 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086064489_392.las
# Found 1307909 nearby points.
# Saved 435930 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086064489_392.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1086074770_19097.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1086200478_19118.las already exists. Skipping...
# Loaded 48 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086219650_39835.las
# Found 638818 nearby points.
# Saved 216705 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086219650_39835.las
# Loaded 8 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086219659_39836.las
# Found 172448 nearby points.
# Saved 68390 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086219659_39836.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663407_19180.las
# Found 290508 nearby points.
# Saved 101072 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663407_19180.las
# Loaded 39 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663427_1143.las
# Found 587623 nearby points.
# Saved 200953 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663427_1143.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663436_19185.las
# Found 76264 nearby points.
# Saved 33339 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663436_19185.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663447_19184.las
# Found 174517 nearby points.
# Saved 64110 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663447_19184.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663456_19177.las
# Found 362696 nearby points.
# Saved 127214 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663456_19177.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663462_1146.las
# Found 218828 nearby points.
# Saved 80292 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663462_1146.las
# Loaded 86 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086663468_18337.las
# Found 1194489 nearby points.
# Saved 393527 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086663468_18337.las
# Loaded 822 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1086753139_18690.las
# Found 17285544 nearby points.
# Saved 3178143 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086753139_18690.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1086896390_9834.las already exists. Skipping...
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027678_18313.las
# Found 60946 nearby points.
# Saved 28312 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027678_18313.las
# Loaded 135 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027693_18353.las
# Found 2343929 nearby points.
# Saved 755314 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027693_18353.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027702_18321.las
# Found 337289 nearby points.
# Saved 124655 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027702_18321.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027706_18318.las
# Found 365042 nearby points.
# Saved 137477 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027706_18318.las
# Loaded 24 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027715_18317.las
# Found 404039 nearby points.
# Saved 145839 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027715_18317.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027721_18314.las
# Found 747480 nearby points.
# Saved 257309 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027721_18314.las
# Loaded 43 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027737_18356.las
# Found 680074 nearby points.
# Saved 225241 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027737_18356.las
# Loaded 62 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027750_18354.las
# Found 902112 nearby points.
# Saved 291140 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027750_18354.las
# Loaded 170 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087027785_18370.las
# Found 3554341 nearby points.
# Saved 1137403 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087027785_18370.las
# Loaded 14 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087150259_18328.las
# Found 204746 nearby points.
# Saved 75602 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087150259_18328.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087150268_18325.las
# Found 195788 nearby points.
# Saved 73035 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087150268_18325.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1087159695_18320.las
# Found 530486 nearby points.
# Saved 191318 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1087159695_18320.las
# Loaded 258 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1089790854_34845.las
# Found 4065908 nearby points.
# Saved 1385861 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1089790854_34845.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660329_9853.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660341_9828.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660353_9839.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660365_9838.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660403_9792.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660412_9797.las already exists. Skipping...
# Loaded 48 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1091830454_19222.las
# Found 657296 nearby points.
# Saved 226104 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091830454_19222.las
# Loaded 63 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1091830473_19218.las
# Found 1438245 nearby points.
# Saved 477315 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091830473_19218.las
# Loaded 210 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1091830479_19213.las
# Found 3850770 nearby points.
# Saved 1261689 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091830479_19213.las
# Loaded 745 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1091877517_18687.las
# Found 17569156 nearby points.
# Saved 2279875 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091877517_18687.las
# Loaded 59 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1091877559_17325.las
# Found 1295044 nearby points.
# Saved 448476 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091877559_17325.las
# Loaded 232 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092077907_390.las
# Found 3923561 nearby points.
# Saved 572225 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092077907_390.las
# Loaded 49 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092165132_19188.las
# Found 166741 nearby points.
# Saved 59135 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092165132_19188.las
# Loaded 251 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092205249_6427.las
# Found 5584480 nearby points.
# Saved 1812085 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092205249_6427.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092205255_6421.las
# Found 422878 nearby points.
# Saved 142132 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092205255_6421.las
# Loaded 39 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092205277_6416.las
# Found 595859 nearby points.
# Saved 211416 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092205277_6416.las
# Loaded 14 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092205283_6417.las
# Found 206256 nearby points.
# Saved 70638 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092205283_6417.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395190_19172.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395197_1279.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395206_19169.las already exists. Skipping...
# Loaded 31 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092395305_19165.las
# Found 386606 nearby points.
# Saved 131953 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395305_19165.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092411041_19183.las
# Found 438637 nearby points.
# Saved 157807 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411041_19183.las
# Loaded 35 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092411073_19159.las
# Found 830450 nearby points.
# Saved 279628 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411073_19159.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411082_1277.las already exists. Skipping...
# Loaded 41 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092411088_19174.las
# Found 491021 nearby points.
# Saved 164654 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411088_19174.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411103_19166.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411112_1276.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411124_1275.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438839_19090.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438882_19098.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438891_19101.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438898_19102.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438907_19143.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438934_19141.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438957_19160.las already exists. Skipping...
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092438970_19163.las
# Found 578874 nearby points.
# Saved 195073 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438970_19163.las
# Loaded 188 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092491873_18273.las
# Found 2844263 nearby points.
# Saved 950753 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092491873_18273.las
# Loaded 285 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092491881_1297.las
# Found 7606759 nearby points.
# Saved 2429254 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092491881_1297.las
# Loaded 24 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092504517_18315.las
# Found 759952 nearby points.
# Saved 267381 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092504517_18315.las
# Loaded 9 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1092504589_18308.las
# Found 171253 nearby points.
# Saved 69981 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092504589_18308.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1235999016_689.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1235999072_671.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047756_9802.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047802_687.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047811_9783.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895188_685.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895251_9801.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895257_9803.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895263_9800.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1322605320_45404.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1322605426_45440.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1322990815_45415.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1322990843_45431.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323011802_45425.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323090759_45426.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323090765_45488.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323122043_19145.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323122063_993.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1323187684_45438.las already exists. Skipping...
# Loaded 65 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1323187749_45462.las
# Found 537647 nearby points.
# Saved 176183 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323187749_45462.las
# Loaded 21 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1332095208_17638.las
# Found 328852 nearby points.
# Saved 113852 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1332095208_17638.las
# Loaded 105 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1332114369_17637.las
# Found 1987520 nearby points.
# Saved 647316 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1332114369_17637.las
# Loaded 143 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1332114378_17289.las
# Found 3307257 nearby points.
# Saved 1087742 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1332114378_17289.las
# Loaded 54 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1332114384_17636.las
# Found 770437 nearby points.
# Saved 256105 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1332114384_17636.las
# Loaded 10 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336017966_18341.las
# Found 187432 nearby points.
# Saved 74244 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336017966_18341.las
# Loaded 149 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336017975_1272.las
# Found 3230108 nearby points.
# Saved 1067578 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336017975_1272.las
# Loaded 64 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336017981_18342.las
# Found 1391901 nearby points.
# Saved 461890 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336017981_18342.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336554934_18298.las
# Found 46892 nearby points.
# Saved 31368 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336554934_18298.las
# Loaded 51 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336674569_18294.las
# Found 744979 nearby points.
# Saved 257733 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336674569_18294.las
# Loaded 60 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336688467_18302.las
# Found 1102861 nearby points.
# Saved 380403 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336688467_18302.las
# Loaded 26 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336688546_18350.las
# Found 452804 nearby points.
# Saved 156381 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336688546_18350.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336688555_18343.las
# Found 417978 nearby points.
# Saved 147161 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336688555_18343.las
# Loaded 50 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1336751077_18283.las
# Found 1167197 nearby points.
# Saved 413634 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1336751077_18283.las
# Loaded 39 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1337053989_18311.las
# Found 604342 nearby points.
# Saved 205282 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1337053989_18311.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1338556271_19085.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1338561961_19121.las already exists. Skipping...
# Loaded 118 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1338588658_19119.las
# Found 2191914 nearby points.
# Saved 704790 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1338588658_19119.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1338588667_19120.las already exists. Skipping...
# Loaded 49 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1339942280_2210.las
# Found 798485 nearby points.
# Saved 266843 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1339942280_2210.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1339942289_2213.las
# Found 261599 nearby points.
# Saved 97522 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1339942289_2213.las
# Loaded 81 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340022225_2222.las
# Found 2586550 nearby points.
# Saved 856020 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340022225_2222.las
# Loaded 290 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340039042_2225.las
# Found 8985873 nearby points.
# Saved 1463516 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340039042_2225.las
# Loaded 45 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340050946_2230.las
# Found 707270 nearby points.
# Saved 239288 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340050946_2230.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340050979_2235.las
# Found 289438 nearby points.
# Saved 110083 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340050979_2235.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340050983_2236.las
# Found 465415 nearby points.
# Saved 167192 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340050983_2236.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340059175_2231.las
# Found 201969 nearby points.
# Saved 63495 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340059175_2231.las
# Loaded 76 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340516457_17341.las
# Found 1135437 nearby points.
# Saved 384372 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340516457_17341.las
# Loaded 46 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611839_17290.las
# Found 644039 nearby points.
# Saved 221585 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611839_17290.las
# Loaded 34 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611848_17301.las
# Found 899452 nearby points.
# Saved 305587 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611848_17301.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611860_17292.las
# Found 342294 nearby points.
# Saved 121056 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611860_17292.las
# Loaded 29 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611869_17293.las
# Found 404421 nearby points.
# Saved 140975 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611869_17293.las
# Loaded 8 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611876_17296.las
# Found 105671 nearby points.
# Saved 44012 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611876_17296.las
# Loaded 26 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611881_17297.las
# Found 400645 nearby points.
# Saved 138550 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611881_17297.las
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611890_17299.las
# Found 446034 nearby points.
# Saved 157316 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611890_17299.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340611897_17298.las
# Found 208429 nearby points.
# Saved 67788 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340611897_17298.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340663375_17291.las
# Found 153683 nearby points.
# Saved 48393 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340663375_17291.las
# Loaded 37 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1340663389_17294.las
# Found 508042 nearby points.
# Saved 176555 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1340663389_17294.las
# Loaded 70 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1341251496_1657.las
# Found 1671279 nearby points.
# Saved 554828 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341251496_1657.las
# Loaded 65 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1341446482_1637.las
# Found 1037411 nearby points.
# Saved 344926 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341446482_1637.las
# Loaded 22 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1341446491_1638.las
# Found 356242 nearby points.
# Saved 125375 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341446491_1638.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1341696075_9805.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1341696092_9806.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\1341753806_9793.las already exists. Skipping...
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342100529_767.las
# Found 62729 nearby points.
# Saved 29316 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342100529_767.las
# Loaded 194 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342100576_764.las
# Found 3510366 nearby points.
# Saved 1154164 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342100576_764.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342640065_18696.las
# Found 464705 nearby points.
# Saved 159466 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342640065_18696.las
# Loaded 92 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342831003_250.las
# Found 1026539 nearby points.
# Saved 334677 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342831003_250.las
# Loaded 125 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342904391_39811.las
# Found 2058110 nearby points.
# Saved 680764 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342904391_39811.las
# Loaded 94 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342904400_39805.las
# Found 1290940 nearby points.
# Saved 434375 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342904400_39805.las
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342945276_39832.las
# Found 452288 nearby points.
# Saved 153477 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1342945276_39832.las
# Loaded 234 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\1342952203_39806.las
# Found 3806120 nearby points.
# ...
# Loaded 65 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425505_1647.las
# Found 936423 nearby points.
# Saved 312316 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425505_1647.las
# Loaded 17 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425589_1671.las
# Found 241797 nearby points.
# Saved 88248 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425589_1671.las
# Loaded 52 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425595_1663.las
# Found 762825 nearby points.
# Saved 259067 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425595_1663.las
# Loaded 128 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425613_1627.las
# Found 1681618 nearby points.
# Saved 578635 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425613_1627.las
# Loaded 145 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425619_1061.las
# Found 2975592 nearby points.
# Saved 988117 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425619_1061.las
# Loaded 31 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425667_1644.las
# Found 770665 nearby points.
# Saved 263902 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425667_1644.las
# Loaded 134 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425685_1625.las
# Found 1812946 nearby points.
# Saved 621304 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425685_1625.las
# Loaded 44 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425708_17281.las
# Found 1095346 nearby points.
# Saved 371993 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425708_17281.las
# Loaded 212 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425714_1642.las
# Found 3604688 nearby points.
# Saved 1177263 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425714_1642.las
# Loaded 94 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425726_1649.las
# Found 2181333 nearby points.
# Saved 717289 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425726_1649.las
# Loaded 124 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425732_1623.las
# Found 1919705 nearby points.
# Saved 643180 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425732_1623.las
# Loaded 59 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425743_1670.las
# Found 1007280 nearby points.
# Saved 330070 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425743_1670.las
# Loaded 139 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425761_1626.las
# Found 2217944 nearby points.
# Saved 734019 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425761_1626.las
# Loaded 161 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425767_17311.las
# Found 2818880 nearby points.
# Saved 919128 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425767_17311.las
# Loaded 42 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425773_17313.las
# Found 566305 nearby points.
# Saved 191884 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425773_17313.las
# Loaded 31 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425779_17312.las
# Found 347027 nearby points.
# Saved 119793 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425779_17312.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362425785_1620.las
# Found 200591 nearby points.
# Saved 61345 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362425785_1620.las
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430819_2209.las
# Found 775762 nearby points.
# Saved 266537 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430819_2209.las
# Loaded 84 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430879_2203.las
# Found 1988937 nearby points.
# Saved 660677 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430879_2203.las
# Loaded 98 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430885_2214.las
# Found 1641557 nearby points.
# Saved 544621 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430885_2214.las
# Loaded 41 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430891_2215.las
# Found 639653 nearby points.
# Saved 217449 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430891_2215.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430915_2211.las
# Found 140299 nearby points.
# Saved 54968 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430915_2211.las
# Loaded 23 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430927_2157.las
# Found 295750 nearby points.
# Saved 102839 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430927_2157.las
# Loaded 83 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430939_2243.las
# Found 1361380 nearby points.
# Saved 454232 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430939_2243.las
# Loaded 120 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430951_2241.las
# Found 2297096 nearby points.
# Saved 772225 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430951_2241.las
# Loaded 81 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362430963_2242.las
# Found 1791710 nearby points.
# Saved 587830 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362430963_2242.las
# Loaded 49 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431083_2217.las
# Found 863254 nearby points.
# Saved 284993 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431083_2217.las
# Loaded 92 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431207_2216.las
# Found 1675334 nearby points.
# Saved 558848 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431207_2216.las
# Loaded 55 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431213_2208.las
# Found 587683 nearby points.
# Saved 193895 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431213_2208.las
# Loaded 95 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431393_2207.las
# Found 2130366 nearby points.
# Saved 699087 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431393_2207.las
# Loaded 73 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431399_2205.las
# Found 1032728 nearby points.
# Saved 347510 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431399_2205.las
# Loaded 311 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431429_2204.las
# Found 5199001 nearby points.
# Saved 1667426 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431429_2204.las
# Loaded 125 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431465_2219.las
# Found 2867762 nearby points.
# Saved 937080 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431465_2219.las
# Loaded 254 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362431878_2228.las
# Found 4679864 nearby points.
# Saved 1516979 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362431878_2228.las
# Loaded 196 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\362471526_7684.las
# Found 943535 nearby points.
# Saved 316570 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362471526_7684.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\362471542_45456.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\362473668_9795.las already exists. Skipping...
# Loaded 34 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\363875179_17643.las
# Found 502090 nearby points.
# Saved 174549 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\363875179_17643.las
# Loaded 257 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364413576_18279.las
# Found 5625504 nearby points.
# Saved 1850065 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364413576_18279.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\364413600_19167.las already exists. Skipping...
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\364413952_19109.las already exists. Skipping...
# Loaded 188 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364414020_18371.las
# Found 3447439 nearby points.
# Saved 1125445 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364414020_18371.las
# Loaded 332 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364440393_19236.las
# Found 6840910 nearby points.
# Saved 2214546 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364440393_19236.las
# Loaded 53 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364440409_17323.las
# Found 698450 nearby points.
# Saved 245176 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364440409_17323.las
# Loaded 121 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364440703_39819.las
# Found 1814769 nearby points.
# Saved 604687 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364440703_39819.las
# Loaded 82 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\364441752_18693.las
# Found 1433288 nearby points.
# Saved 478448 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364441752_18693.las
# Loaded 71 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461794905_34785.las
# Found 939277 nearby points.
# Saved 309306 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461794905_34785.las
# Loaded 41 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461794911_1643.las
# Found 668721 nearby points.
# Saved 225345 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461794911_1643.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\461794926_19149.las already exists. Skipping...
# Loaded 98 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461795395_19216.las
# Found 1641064 nearby points.
# Saved 562697 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461795395_19216.las
# Loaded 64 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461795414_34784.las
# Found 932476 nearby points.
# Saved 311449 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461795414_34784.las
# Output file E:\ALS_DATA\NLS_20p_EVO_road_patches\461795483_19150.las already exists. Skipping...
# Loaded 241 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461796923_1641.las
# Found 3433122 nearby points.
# Saved 1130236 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461796923_1641.las
# Loaded 144 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461797101_17300.las
# Found 2063457 nearby points.
# Saved 676679 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461797101_17300.las
# Loaded 54 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\461797943_34834.las
# Found 1322218 nearby points.
# Saved 436855 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461797943_34834.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\5360326_17658.las
# Found 55758 nearby points.
# Saved 24487 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\5360326_17658.las
# Loaded 114 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\5360335_17657.las
# Found 1181412 nearby points.
# Saved 397170 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\5360335_17657.las
# Loaded 7 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\7656784_17331.las
# Found 66971 nearby points.
# Saved 28822 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\7656784_17331.las
# Loaded 38 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\7656793_17329.las
# Found 420838 nearby points.
# Saved 148871 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\7656793_17329.las
# Loaded 8 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\7656817_17330.las
# Found 74102 nearby points.
# Saved 30005 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\7656817_17330.las
# Loaded 106 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\7656869_17315.las
# Found 1674898 nearby points.
# Saved 565290 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\7656869_17315.las
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\8050789_1674.las
# Found 92361 nearby points.
# Saved 43714 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\8050789_1674.las
# Loaded 43 trajectory points from C:\Users\telukkari\Documents\Python\forest_road_change_detection\data\road_vecs_las_Padasjoki_20231023\960228308_45495.las
# Found 461898 nearby points.
# Saved 155188 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\960228308_45495.las
