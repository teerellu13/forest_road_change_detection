# %%
# This script is for creating road patches from 20p data that correspond to road patches of 5p data. 
# Paula's road vectors are used for this purpose. Some of these road vectors may contain NaN values.

# %%
east_min = 395000.0 # 395500.0 
east_max = 407000.0 # 400500.0 
north_min = 6783000.0 # 6783500.0 
north_max = 6795000.0 # 6788500.0 

print(east_max-east_min)
print(north_max-north_min)
# Out:
# 12000.0
# 12000.0

# %%
import os
import re
import math
import shutil
import laspy
import numpy as np

def parse_tile_coordinates(filename):
    """Extract x and y tile coordinates from the filename."""
    match = re.search(r"tile_x_(\d+)_y_(\d+)\.laz", filename)
    if match:
        x = int(match.group(1))
        y = int(match.group(2))
        return x, y
    return None

def find_n_closest_tiles(point, folder_path, n):
    """Find the four tiles whose (x, y) are closest to the given 3D point's (x, y)."""
    point_x, point_y, _ = point  # Ignore z
    distances = []

    for filename in os.listdir(folder_path):
        if filename.endswith('.laz'):
            coords = parse_tile_coordinates(filename)
            if coords:
                tile_x, tile_y = coords

                dist = math.hypot(tile_x - point_x, tile_y - point_y)
                distances.append((dist, filename))

    # Sort by distance and get the four closest files
    distances.sort()
    closest_files = [filename for _, filename in distances[:n]]

    return closest_files

# %%
folder_road_vectors = r"C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023"
folder_tiles = r"E:\ALS_DATA\NLS_20p_EVO_TILES" 
output_folder = r"E:\ALS_DATA\NLS_20p_EVO_road_patches"

for file_road_vector in os.listdir(folder_road_vectors):
    file_path_road_vector = os.path.join(folder_road_vectors, file_road_vector)
    road_vector = laspy.read(file_path_road_vector)
    points_road_vector = np.vstack((road_vector.x, road_vector.y, road_vector.z)).T

    east_min = 395000.0 # 395500.0 
    east_max = 407000.0 # 400500.0 
    north_min = 6783000.0 # 6783500.0 
    north_max = 6795000.0 # 6788500.0 

    if points_road_vector.shape[0] == 0:
        continue
    if points_road_vector[0,0] > east_min and points_road_vector[0,0] < east_max and points_road_vector[0,1] > north_min and points_road_vector[0,1] < north_max:
        print(f"Loaded {len(points_road_vector)} trajectory points from {file_path_road_vector}")

        # TODO check that road vector does not contain NaN values
        # TODO add points if the distance between two consecutive points is too large

        all_nearby_points = None

        for point in points_road_vector:
            #print(f"Trajectory Point: {point}")
            closest_tiles = find_n_closest_tiles(point, folder_tiles, n=4)

            for tile_name in closest_tiles:
                tile_path = os.path.join(folder_tiles, tile_name)
                tile = laspy.read(tile_path)  

                # tile_points = np.vstack((tile.x, tile.y, tile.z, tile.intensity)).T #, tile.scan_angle_rank, tile.return_number, tile.gps_time, tile.Amplitude, tile.Deviation)).T

                # Compute horizontal distance to current trajectory point
                dx = tile.x - point[0]
                dy = tile.y - point[1]
                horizontal_dist = np.sqrt(dx**2 + dy**2)

                nearby_mask = horizontal_dist <= 10
                nearby_points = tile.points[nearby_mask]
                # nearby_points = tile_points[nearby_mask]
                if nearby_points.size > 0:
                    if all_nearby_points == None:
                        all_nearby_points = nearby_points
                    else:
                        all_nearby_points = np.hstack([all_nearby_points, nearby_points])
                    # all_road_patch_points.append(nearby_points)

        print(f"Found {len(all_nearby_points)} nearby points.")

        # Stack all filtered points into one numpy array
        # if all_nearby_points:
        #     stacked_points = np.vstack(all_road_patch_points)
        # else:
        #     stacked_points = np.empty((0, 9))

        if all_nearby_points == None:
            all_nearby_points = np.empty((0, 9))

        # 1. Remove duplicate rows (points)
        unique_points = np.unique(all_nearby_points, axis=0)

        # 2. Create a new LAS file with the unique points
        header = laspy.LasHeader(point_format=6, version="1.4")
        las = laspy.LasData(header)

        las.points = unique_points

        # las.x = unique_points[:, 0]
        # las.y = unique_points[:, 1]
        # las.z = unique_points[:, 2]
        # las.intensity = unique_points[:,3]
        # las.scan_angle = unique_points[:,4]
        # las.return_number = unique_points[:,5]
        # las.gps_time = unique_points[:,6]
        # las.Amplitude = unique_points[:,7]
        # las.Deviation = unique_points[:,8]

        # 3. Save the LAS file
        output_path = os.path.join(output_folder, f"{file_road_vector}")
        # las.write(output_path)

        print(f"Saved {len(unique_points)} unique points to {output_path}")
# Out:
# Loaded 7 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1077366617_45474.las
# Found 13 nearby points in tile ['tile_x_396125_y_6783725.laz', 'tile_x_396075_y_6783725.laz', 'tile_x_396125_y_6783775.laz', 'tile_x_396075_y_6783775.laz']
# Saved 31255 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1077366617_45474.las
# Loaded 38 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080419324_45480.las
# Found 74 nearby points in tile ['tile_x_397775_y_6783625.laz', 'tile_x_397775_y_6783675.laz', 'tile_x_397725_y_6783625.laz', 'tile_x_397725_y_6783675.laz']
# Saved 232858 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419324_45480.las
# Loaded 154 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080419383_45429.las
# Found 303 nearby points in tile ['tile_x_396475_y_6785325.laz', 'tile_x_396425_y_6785325.laz', 'tile_x_396475_y_6785275.laz', 'tile_x_396425_y_6785275.laz']
# Saved 671942 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419383_45429.las
# Loaded 94 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080419475_997.las
# Found 158 nearby points in tile ['tile_x_396525_y_6785825.laz', 'tile_x_396575_y_6785825.laz', 'tile_x_396525_y_6785775.laz', 'tile_x_396525_y_6785875.laz']
# Saved 550830 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080419475_997.las
# Loaded 58 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080487225_45422.las
# Found 121 nearby points in tile ['tile_x_397425_y_6784925.laz', 'tile_x_397475_y_6784925.laz', 'tile_x_397425_y_6784975.laz', 'tile_x_397475_y_6784975.laz']
# Saved 248486 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487225_45422.las
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080487234_45424.las
# Found 11 nearby points in tile ['tile_x_397225_y_6784725.laz', 'tile_x_397275_y_6784725.laz', 'tile_x_397225_y_6784775.laz', 'tile_x_397275_y_6784775.laz']
# Saved 33313 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487234_45424.las
# Loaded 53 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080487241_45420.las
# Found 97 nearby points in tile ['tile_x_397475_y_6784725.laz', 'tile_x_397525_y_6784725.laz', 'tile_x_397475_y_6784675.laz', 'tile_x_397525_y_6784675.laz']
# Saved 297065 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487241_45420.las
# Loaded 17 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1080487250_45423.las
# Found 49 nearby points in tile ['tile_x_397225_y_6784725.laz', 'tile_x_397275_y_6784725.laz', 'tile_x_397225_y_6784675.laz', 'tile_x_397275_y_6784675.laz']
# Saved 80891 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1080487250_45423.las
# Loaded 50 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1081001846_47112.las
# Found 97 nearby points in tile ['tile_x_397125_y_6788325.laz', 'tile_x_397075_y_6788325.laz', 'tile_x_397125_y_6788275.laz', 'tile_x_397125_y_6788375.laz']
# Saved 351831 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1081001846_47112.las
# Loaded 103 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1083742875_19152.las
# Found 28 nearby points in tile ['tile_x_398225_y_6783525.laz', 'tile_x_398175_y_6783525.laz', 'tile_x_398275_y_6783525.laz', 'tile_x_398125_y_6783525.laz']
# Saved 45531 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1083742875_19152.las
# Loaded 18 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1085187404_9835.las
# Found 30 nearby points in tile ['tile_x_398975_y_6786025.laz', 'tile_x_398975_y_6785975.laz', 'tile_x_399025_y_6786025.laz', 'tile_x_399025_y_6785975.laz']
# Saved 111016 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1085187404_9835.las
# Loaded 23 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1086074770_19097.las
# Found 40 nearby points in tile ['tile_x_398375_y_6785675.laz', 'tile_x_398425_y_6785675.laz', 'tile_x_398375_y_6785725.laz', 'tile_x_398425_y_6785725.laz']
# Saved 157131 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086074770_19097.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1086200478_19118.las
# Found 29 nearby points in tile ['tile_x_400525_y_6785475.laz', 'tile_x_400525_y_6785525.laz', 'tile_x_400475_y_6785475.laz', 'tile_x_400475_y_6785525.laz']
# Saved 86918 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086200478_19118.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1086896390_9834.las
# Found 36 nearby points in tile ['tile_x_398975_y_6786025.laz', 'tile_x_398975_y_6785975.laz', 'tile_x_399025_y_6786025.laz', 'tile_x_399025_y_6785975.laz']
# Saved 95217 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1086896390_9834.las
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660329_9853.las
# Found 80 nearby points in tile ['tile_x_398625_y_6786075.laz', 'tile_x_398625_y_6786125.laz', 'tile_x_398575_y_6786075.laz', 'tile_x_398575_y_6786125.laz']
# Saved 196749 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660329_9853.las
# Loaded 56 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660341_9828.las
# Found 119 nearby points in tile ['tile_x_398875_y_6786025.laz', 'tile_x_398825_y_6786025.laz', 'tile_x_398875_y_6786075.laz', 'tile_x_398825_y_6786075.laz']
# Saved 325201 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660341_9828.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660353_9839.las
# Found 2 nearby points in tile ['tile_x_398875_y_6786025.laz', 'tile_x_398825_y_6786025.laz', 'tile_x_398875_y_6785975.laz', 'tile_x_398875_y_6786075.laz']
# Saved 16464 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660353_9839.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660365_9838.las
# Found 22 nearby points in tile ['tile_x_398925_y_6785975.laz', 'tile_x_398875_y_6785975.laz', 'tile_x_398925_y_6785925.laz', 'tile_x_398875_y_6785925.laz']
# Saved 69608 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660365_9838.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660403_9792.las
# Found 37 nearby points in tile ['tile_x_398925_y_6786975.laz', 'tile_x_398925_y_6786925.laz', 'tile_x_398875_y_6786975.laz', 'tile_x_398875_y_6786925.laz']
# Saved 91958 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660403_9792.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1091660412_9797.las
# Found 11 nearby points in tile ['tile_x_398925_y_6787075.laz', 'tile_x_398925_y_6787125.laz', 'tile_x_398975_y_6787075.laz', 'tile_x_398875_y_6787075.laz']
# Saved 27531 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1091660412_9797.las
# Loaded 30 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092395190_19172.las
# Found 69 nearby points in tile ['tile_x_398825_y_6784075.laz', 'tile_x_398775_y_6784075.laz', 'tile_x_398825_y_6784125.laz', 'tile_x_398775_y_6784125.laz']
# Saved 164008 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395190_19172.las
# Loaded 28 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092395197_1279.las
# Found 48 nearby points in tile ['tile_x_398825_y_6784075.laz', 'tile_x_398775_y_6784075.laz', 'tile_x_398825_y_6784025.laz', 'tile_x_398825_y_6784125.laz']
# Saved 156394 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395197_1279.las
# Loaded 35 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092395206_19169.las
# Found 68 nearby points in tile ['tile_x_398875_y_6784175.laz', 'tile_x_398925_y_6784175.laz', 'tile_x_398875_y_6784125.laz', 'tile_x_398925_y_6784125.laz']
# Saved 183364 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092395206_19169.las
# Loaded 44 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092411082_1277.las
# Found 101 nearby points in tile ['tile_x_400525_y_6783875.laz', 'tile_x_400525_y_6783825.laz', 'tile_x_400475_y_6783875.laz', 'tile_x_400475_y_6783825.laz']
# Saved 234139 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411082_1277.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092411103_19166.las
# Found 18 nearby points in tile ['tile_x_399675_y_6783925.laz', 'tile_x_399675_y_6783875.laz', 'tile_x_399725_y_6783925.laz', 'tile_x_399725_y_6783875.laz']
# Saved 68350 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411103_19166.las
# Loaded 146 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092411112_1276.las
# Found 284 nearby points in tile ['tile_x_399675_y_6783875.laz', 'tile_x_399675_y_6783925.laz', 'tile_x_399725_y_6783875.laz', 'tile_x_399725_y_6783925.laz']
# Saved 934484 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411112_1276.las
# Loaded 160 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092411124_1275.las
# Found 302 nearby points in tile ['tile_x_399625_y_6783575.laz', 'tile_x_399625_y_6783625.laz', 'tile_x_399575_y_6783575.laz', 'tile_x_399575_y_6783625.laz']
# Saved 1084079 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092411124_1275.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438839_19090.las
# Found 20 nearby points in tile ['tile_x_398925_y_6785975.laz', 'tile_x_398925_y_6785925.laz', 'tile_x_398875_y_6785975.laz', 'tile_x_398875_y_6785925.laz']
# Saved 75426 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438839_19090.las
# Loaded 19 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438882_19098.las
# Found 30 nearby points in tile ['tile_x_398225_y_6785725.laz', 'tile_x_398225_y_6785775.laz', 'tile_x_398175_y_6785725.laz', 'tile_x_398275_y_6785725.laz']
# Saved 73724 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438882_19098.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438891_19101.las
# Found 53 nearby points in tile ['tile_x_398225_y_6785625.laz', 'tile_x_398225_y_6785675.laz', 'tile_x_398275_y_6785625.laz', 'tile_x_398275_y_6785675.laz']
# Saved 131864 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438891_19101.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438898_19102.las
# Found 25 nearby points in tile ['tile_x_398125_y_6785575.laz', 'tile_x_398125_y_6785625.laz', 'tile_x_398075_y_6785575.laz', 'tile_x_398075_y_6785625.laz']
# Saved 70456 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438898_19102.las
# Loaded 32 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438907_19143.las
# Found 64 nearby points in tile ['tile_x_398175_y_6785525.laz', 'tile_x_398175_y_6785575.laz', 'tile_x_398125_y_6785525.laz', 'tile_x_398125_y_6785575.laz']
# Saved 158940 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438907_19143.las
# Loaded 23 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438934_19141.las
# Found 32 nearby points in tile ['tile_x_398375_y_6784625.laz', 'tile_x_398375_y_6784575.laz', 'tile_x_398325_y_6784625.laz', 'tile_x_398425_y_6784625.laz']
# Saved 160417 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438934_19141.las
# Loaded 17 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1092438957_19160.las
# Found 22 nearby points in tile ['tile_x_400325_y_6783725.laz', 'tile_x_400325_y_6783775.laz', 'tile_x_400275_y_6783725.laz', 'tile_x_400275_y_6783775.laz']
# Saved 83853 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1092438957_19160.las
# Loaded 23 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1235999016_689.las
# Found 39 nearby points in tile ['tile_x_398825_y_6786875.laz', 'tile_x_398825_y_6786825.laz', 'tile_x_398775_y_6786875.laz', 'tile_x_398775_y_6786825.laz']
# Saved 101308 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1235999016_689.las
# Loaded 182 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1235999072_671.las
# Found 326 nearby points in tile ['tile_x_398925_y_6786925.laz', 'tile_x_398875_y_6786925.laz', 'tile_x_398925_y_6786875.laz', 'tile_x_398875_y_6786875.laz']
# Saved 945499 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1235999072_671.las
# Loaded 34 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1236047756_9802.las
# Found 50 nearby points in tile ['tile_x_399275_y_6787025.laz', 'tile_x_399275_y_6786975.laz', 'tile_x_399225_y_6787025.laz', 'tile_x_399225_y_6786975.laz']
# Saved 163208 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047756_9802.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1236047802_687.las
# Found 24 nearby points in tile ['tile_x_399225_y_6787525.laz', 'tile_x_399175_y_6787525.laz', 'tile_x_399225_y_6787575.laz', 'tile_x_399175_y_6787575.laz']
# Saved 100545 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047802_687.las
# Loaded 51 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1236047811_9783.las
# Found 121 nearby points in tile ['tile_x_399175_y_6787475.laz', 'tile_x_399175_y_6787525.laz', 'tile_x_399225_y_6787475.laz', 'tile_x_399225_y_6787525.laz']
# Saved 397107 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1236047811_9783.las
# Loaded 17 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1304895188_685.las
# Found 39 nearby points in tile ['tile_x_399625_y_6787575.laz', 'tile_x_399625_y_6787625.laz', 'tile_x_399675_y_6787575.laz', 'tile_x_399575_y_6787575.laz']
# Saved 78163 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895188_685.las
# Loaded 8 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1304895251_9801.las
# Found 23 nearby points in tile ['tile_x_399225_y_6787025.laz', 'tile_x_399225_y_6786975.laz', 'tile_x_399175_y_6787025.laz', 'tile_x_399175_y_6786975.laz']
# Saved 76282 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895251_9801.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1304895257_9803.las
# Found 18 nearby points in tile ['tile_x_399275_y_6787025.laz', 'tile_x_399275_y_6786975.laz', 'tile_x_399225_y_6787025.laz', 'tile_x_399225_y_6786975.laz']
# Saved 36090 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895257_9803.las
# Loaded 18 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1304895263_9800.las
# Found 48 nearby points in tile ['tile_x_399325_y_6786975.laz', 'tile_x_399325_y_6787025.laz', 'tile_x_399375_y_6786975.laz', 'tile_x_399375_y_6787025.laz']
# Saved 70085 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1304895263_9800.las
# Loaded 85 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1322605320_45404.las
# Found 143 nearby points in tile ['tile_x_396625_y_6785425.laz', 'tile_x_396675_y_6785425.laz', 'tile_x_396625_y_6785375.laz', 'tile_x_396675_y_6785375.laz']
# Saved 515299 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1322605320_45404.las
# Loaded 52 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1322605426_45440.las
# Found 104 nearby points in tile ['tile_x_395725_y_6785675.laz', 'tile_x_395725_y_6785725.laz', 'tile_x_395775_y_6785675.laz', 'tile_x_395675_y_6785675.laz']
# Saved 356021 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1322605426_45440.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1322990815_45415.las
# Found 51 nearby points in tile ['tile_x_397425_y_6785425.laz', 'tile_x_397425_y_6785375.laz', 'tile_x_397375_y_6785425.laz', 'tile_x_397475_y_6785425.laz']
# Saved 129264 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1322990815_45415.las
# Loaded 26 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1322990843_45431.las
# Found 62 nearby points in tile ['tile_x_396925_y_6785525.laz', 'tile_x_396875_y_6785525.laz', 'tile_x_396925_y_6785575.laz', 'tile_x_396875_y_6785575.laz']
# Saved 302240 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1322990843_45431.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323011802_45425.las
# Found 16 nearby points in tile ['tile_x_397225_y_6784625.laz', 'tile_x_397275_y_6784625.laz', 'tile_x_397225_y_6784675.laz', 'tile_x_397275_y_6784675.laz']
# Saved 53340 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323011802_45425.las
# Loaded 15 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323090759_45426.las
# Found 38 nearby points in tile ['tile_x_397225_y_6784625.laz', 'tile_x_397275_y_6784625.laz', 'tile_x_397225_y_6784675.laz', 'tile_x_397275_y_6784675.laz']
# Saved 80081 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323090759_45426.las
# Loaded 192 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323090765_45488.las
# Found 341 nearby points in tile ['tile_x_397175_y_6784625.laz', 'tile_x_397225_y_6784625.laz', 'tile_x_397175_y_6784575.laz', 'tile_x_397225_y_6784575.laz']
# Saved 964045 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323090765_45488.las
# Loaded 56 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323122043_19145.las
# Found 99 nearby points in tile ['tile_x_398025_y_6784425.laz', 'tile_x_398025_y_6784375.laz', 'tile_x_397975_y_6784425.laz', 'tile_x_398075_y_6784425.laz']
# Saved 298765 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323122043_19145.las
# Loaded 55 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323122063_993.las
# Found 115 nearby points in tile ['tile_x_398225_y_6784225.laz', 'tile_x_398175_y_6784225.laz', 'tile_x_398225_y_6784175.laz', 'tile_x_398175_y_6784175.laz']
# Saved 213670 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323122063_993.las
# Loaded 24 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1323187684_45438.las
# Found 69 nearby points in tile ['tile_x_396175_y_6784275.laz', 'tile_x_396225_y_6784275.laz', 'tile_x_396175_y_6784325.laz', 'tile_x_396225_y_6784325.laz']
# Saved 216713 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1323187684_45438.las
# Loaded 130 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1338556271_19085.las
# Found 254 nearby points in tile ['tile_x_399825_y_6784475.laz', 'tile_x_399825_y_6784425.laz', 'tile_x_399875_y_6784475.laz', 'tile_x_399875_y_6784425.laz']
# Saved 815209 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1338556271_19085.las
# Loaded 26 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1338561961_19121.las
# Found 50 nearby points in tile ['tile_x_399825_y_6784475.laz', 'tile_x_399875_y_6784475.laz', 'tile_x_399825_y_6784425.laz', 'tile_x_399875_y_6784425.laz']
# Saved 286170 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1338561961_19121.las
# Loaded 21 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1338588667_19120.las
# Found 26 nearby points in tile ['tile_x_400525_y_6784375.laz', 'tile_x_400525_y_6784325.laz', 'tile_x_400525_y_6784425.laz', 'tile_x_400525_y_6784275.laz']
# Saved 77517 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1338588667_19120.las
# Loaded 28 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1341696075_9805.las
# Found 51 nearby points in tile ['tile_x_398925_y_6786975.laz', 'tile_x_398925_y_6786925.laz', 'tile_x_398975_y_6786975.laz', 'tile_x_398975_y_6786925.laz']
# Saved 102845 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341696075_9805.las
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1341696092_9806.las
# Found 7 nearby points in tile ['tile_x_398925_y_6786925.laz', 'tile_x_398875_y_6786925.laz', 'tile_x_398925_y_6786975.laz', 'tile_x_398875_y_6786975.laz']
# Saved 19941 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341696092_9806.las
# Loaded 34 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1341753806_9793.las
# Found 57 nearby points in tile ['tile_x_399175_y_6787025.laz', 'tile_x_399175_y_6786975.laz', 'tile_x_399225_y_6787025.laz', 'tile_x_399225_y_6786975.laz']
# Saved 265007 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1341753806_9793.las
# Loaded 14 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1350237152_19094.las
# Found 21 nearby points in tile ['tile_x_399075_y_6785725.laz', 'tile_x_399075_y_6785775.laz', 'tile_x_399125_y_6785725.laz', 'tile_x_399125_y_6785775.laz']
# Saved 135694 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1350237152_19094.las
# Loaded 78 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1350237170_19157.las
# Found 143 nearby points in tile ['tile_x_400475_y_6784025.laz', 'tile_x_400425_y_6784025.laz', 'tile_x_400475_y_6784075.laz', 'tile_x_400475_y_6783975.laz']
# Saved 376699 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1350237170_19157.las
# Loaded 171 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1350237174_19156.las
# Found 315 nearby points in tile ['tile_x_400475_y_6784025.laz', 'tile_x_400425_y_6784025.laz', 'tile_x_400475_y_6783975.laz', 'tile_x_400425_y_6783975.laz']
# Saved 1051759 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1350237174_19156.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1419581254_9851.las
# Found 29 nearby points in tile ['tile_x_398175_y_6786025.laz', 'tile_x_398125_y_6786025.laz', 'tile_x_398175_y_6786075.laz', 'tile_x_398125_y_6786075.laz']
# Saved 99049 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1419581254_9851.las
# Loaded 7 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1419581263_9852.las
# Found 10 nearby points in tile ['tile_x_398225_y_6786075.laz', 'tile_x_398225_y_6786125.laz', 'tile_x_398175_y_6786075.laz', 'tile_x_398275_y_6786075.laz']
# Saved 36644 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1419581263_9852.las
# Loaded 19 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1419581321_9830.las
# Found 36 nearby points in tile ['tile_x_399225_y_6786425.laz', 'tile_x_399275_y_6786425.laz', 'tile_x_399225_y_6786475.laz', 'tile_x_399275_y_6786475.laz']
# Saved 96461 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1419581321_9830.las
# Loaded 112 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1432552400_45402.las
# Found 246 nearby points in tile ['tile_x_396175_y_6784425.laz', 'tile_x_396225_y_6784425.laz', 'tile_x_396175_y_6784375.laz', 'tile_x_396225_y_6784375.laz']
# Saved 486341 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1432552400_45402.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1432552415_45458.las
# Found 4 nearby points in tile ['tile_x_395725_y_6784275.laz', 'tile_x_395675_y_6784275.laz', 'tile_x_395725_y_6784225.laz', 'tile_x_395675_y_6784225.laz']
# Saved 15697 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1432552415_45458.las
# Loaded 44 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1432552429_45437.las
# Found 114 nearby points in tile ['tile_x_396225_y_6784425.laz', 'tile_x_396175_y_6784425.laz', 'tile_x_396225_y_6784375.laz', 'tile_x_396175_y_6784375.laz']
# Saved 400057 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1432552429_45437.las
# Loaded 51 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1433696354_45411.las
# Found 106 nearby points in tile ['tile_x_397475_y_6785775.laz', 'tile_x_397525_y_6785775.laz', 'tile_x_397475_y_6785725.laz', 'tile_x_397525_y_6785725.laz']
# Saved 239999 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1433696354_45411.las
# Loaded 79 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1433696372_45408.las
# Found 154 nearby points in tile ['tile_x_397025_y_6785575.laz', 'tile_x_397025_y_6785525.laz', 'tile_x_397075_y_6785575.laz', 'tile_x_396975_y_6785575.laz']
# Saved 456273 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1433696372_45408.las
# Loaded 192 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1682067128_47109.las
# Found 361 nearby points in tile ['tile_x_397825_y_6786675.laz', 'tile_x_397875_y_6786675.laz', 'tile_x_397825_y_6786725.laz', 'tile_x_397825_y_6786625.laz']
# Saved 1202327 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1682067128_47109.las
# Loaded 19 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1878286159_9796.las
# Found 27 nearby points in tile ['tile_x_398925_y_6787175.laz', 'tile_x_398925_y_6787225.laz', 'tile_x_398875_y_6787175.laz', 'tile_x_398975_y_6787175.laz']
# Saved 88846 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1878286159_9796.las
# Loaded 37 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1878286168_9784.las
# Found 73 nearby points in tile ['tile_x_398925_y_6787125.laz', 'tile_x_398875_y_6787125.laz', 'tile_x_398925_y_6787075.laz', 'tile_x_398875_y_6787075.laz']
# Saved 148305 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1878286168_9784.las
# Loaded 98 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1940476478_45461.las
# Found 96 nearby points in tile ['tile_x_395875_y_6783525.laz', 'tile_x_395825_y_6783525.laz', 'tile_x_395925_y_6783525.laz', 'tile_x_395775_y_6783525.laz']
# Saved 187800 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1940476478_45461.las
# Loaded 124 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1940642188_19147.las
# Found 263 nearby points in tile ['tile_x_398575_y_6783525.laz', 'tile_x_398525_y_6783525.laz', 'tile_x_398575_y_6783575.laz', 'tile_x_398525_y_6783575.laz']
# Saved 743843 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1940642188_19147.las
# Loaded 33 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1940704239_45442.las
# Found 68 nearby points in tile ['tile_x_395875_y_6785725.laz', 'tile_x_395875_y_6785675.laz', 'tile_x_395925_y_6785725.laz', 'tile_x_395925_y_6785675.laz']
# Saved 132292 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1940704239_45442.las
# Loaded 48 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1940710105_45444.las
# Found 79 nearby points in tile ['tile_x_395525_y_6785775.laz', 'tile_x_395525_y_6785725.laz', 'tile_x_395525_y_6785825.laz', 'tile_x_395575_y_6785775.laz']
# Saved 301254 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1940710105_45444.las
# Loaded 9 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1940736497_45467.las
# Found 22 nearby points in tile ['tile_x_395925_y_6784025.laz', 'tile_x_395875_y_6784025.laz', 'tile_x_395925_y_6784075.laz', 'tile_x_395925_y_6783975.laz']
# Saved 51884 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1940736497_45467.las
# Loaded 50 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\1958060754_19113.las
# Found 113 nearby points in tile ['tile_x_399425_y_6785475.laz', 'tile_x_399425_y_6785425.laz', 'tile_x_399475_y_6785475.laz', 'tile_x_399475_y_6785425.laz']
# Saved 199366 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\1958060754_19113.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125556469_1003.las
# Found 10 nearby points in tile ['tile_x_397425_y_6783525.laz', 'tile_x_397425_y_6783575.laz', 'tile_x_397375_y_6783525.laz', 'tile_x_397475_y_6783525.laz']
# Saved 27995 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125556469_1003.las
# Loaded 57 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125556472_1001.las
# Found 105 nearby points in tile ['tile_x_397425_y_6783575.laz', 'tile_x_397475_y_6783575.laz', 'tile_x_397425_y_6783525.laz', 'tile_x_397475_y_6783525.laz']
# Saved 256826 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125556472_1001.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125556482_1002.las
# Found 21 nearby points in tile ['tile_x_397425_y_6783525.laz', 'tile_x_397375_y_6783525.laz', 'tile_x_397425_y_6783575.laz', 'tile_x_397375_y_6783575.laz']
# Saved 45050 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125556482_1002.las
# Loaded 5 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125625715_999.las
# Found 8 nearby points in tile ['tile_x_396125_y_6785725.laz', 'tile_x_396075_y_6785725.laz', 'tile_x_396125_y_6785675.laz', 'tile_x_396125_y_6785775.laz']
# Saved 26854 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125625715_999.las
# Loaded 42 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125625718_1000.las
# Found 60 nearby points in tile ['tile_x_396075_y_6785725.laz', 'tile_x_396125_y_6785725.laz', 'tile_x_396075_y_6785775.laz', 'tile_x_396075_y_6785675.laz']
# Saved 192720 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125625718_1000.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2125625728_998.las
# Found 18 nearby points in tile ['tile_x_396125_y_6785725.laz', 'tile_x_396175_y_6785725.laz', 'tile_x_396125_y_6785675.laz', 'tile_x_396125_y_6785775.laz']
# Saved 42066 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2125625728_998.las
# Loaded 174 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2126922601_695.las
# Found 331 nearby points in tile ['tile_x_398525_y_6788375.laz', 'tile_x_398475_y_6788375.laz', 'tile_x_398525_y_6788425.laz', 'tile_x_398475_y_6788425.laz']
# Saved 840920 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2126922601_695.las
# Loaded 6 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2126922616_678.las
# Found 10 nearby points in tile ['tile_x_398525_y_6788375.laz', 'tile_x_398525_y_6788425.laz', 'tile_x_398575_y_6788375.laz', 'tile_x_398575_y_6788425.laz']
# Saved 30068 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2126922616_678.las
# Loaded 108 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2132933052_47101.las
# Found 222 nearby points in tile ['tile_x_396125_y_6786075.laz', 'tile_x_396175_y_6786075.laz', 'tile_x_396125_y_6786025.laz', 'tile_x_396175_y_6786025.laz']
# Saved 645237 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2132933052_47101.las
# Loaded 49 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\2132933061_47114.las
# Found 88 nearby points in tile ['tile_x_396075_y_6786225.laz', 'tile_x_396125_y_6786225.laz', 'tile_x_396075_y_6786275.laz', 'tile_x_396075_y_6786175.laz']
# Saved 194341 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\2132933061_47114.las
# Loaded 260 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357405_1004.las
# Found 16 nearby points in tile ['tile_x_396575_y_6783525.laz', 'tile_x_396625_y_6783525.laz', 'tile_x_396525_y_6783525.laz', 'tile_x_396675_y_6783525.laz']
# Saved 32425 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357405_1004.las
# Loaded 97 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357459_7778.las
# Found 180 nearby points in tile ['tile_x_395825_y_6787575.laz', 'tile_x_395825_y_6787625.laz', 'tile_x_395775_y_6787575.laz', 'tile_x_395775_y_6787625.laz']
# Saved 395729 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357459_7778.las
# Loaded 44 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357465_7780.las
# Found 83 nearby points in tile ['tile_x_396025_y_6787075.laz', 'tile_x_396025_y_6787025.laz', 'tile_x_395975_y_6787075.laz', 'tile_x_395975_y_6787025.laz']
# Saved 152359 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357465_7780.las
# Loaded 153 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357471_7777.las
# Found 282 nearby points in tile ['tile_x_395975_y_6787075.laz', 'tile_x_395975_y_6787025.laz', 'tile_x_396025_y_6787075.laz', 'tile_x_396025_y_6787025.laz']
# Saved 672446 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357471_7777.las
# Loaded 18 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357477_7781.las
# Found 33 nearby points in tile ['tile_x_395975_y_6786975.laz', 'tile_x_395975_y_6786925.laz', 'tile_x_396025_y_6786975.laz', 'tile_x_395925_y_6786975.laz']
# Saved 80979 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357477_7781.las
# Loaded 40 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357525_7931.las
# Found 75 nearby points in tile ['tile_x_396175_y_6786575.laz', 'tile_x_396175_y_6786525.laz', 'tile_x_396125_y_6786575.laz', 'tile_x_396125_y_6786525.laz']
# Saved 179179 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357525_7931.las
# Loaded 56 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357531_7459.las
# Found 98 nearby points in tile ['tile_x_396025_y_6786675.laz', 'tile_x_395975_y_6786675.laz', 'tile_x_396025_y_6786625.laz', 'tile_x_396025_y_6786725.laz']
# Saved 282869 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357531_7459.las
# Loaded 93 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357555_7929.las
# Found 203 nearby points in tile ['tile_x_395925_y_6786125.laz', 'tile_x_395925_y_6786175.laz', 'tile_x_395875_y_6786125.laz', 'tile_x_395875_y_6786175.laz']
# Saved 507158 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357555_7929.las
# Loaded 20 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357561_7932.las
# Found 54 nearby points in tile ['tile_x_396025_y_6786575.laz', 'tile_x_395975_y_6786575.laz', 'tile_x_396025_y_6786625.laz', 'tile_x_395975_y_6786625.laz']
# Saved 108773 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357561_7932.las
# Loaded 59 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357567_47116.las
# Found 111 nearby points in tile ['tile_x_395775_y_6786425.laz', 'tile_x_395825_y_6786425.laz', 'tile_x_395775_y_6786475.laz', 'tile_x_395775_y_6786375.laz']
# Saved 275188 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357567_47116.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357651_45454.las
# Found 28 nearby points in tile ['tile_x_395675_y_6784625.laz', 'tile_x_395725_y_6784625.laz', 'tile_x_395675_y_6784675.laz', 'tile_x_395725_y_6784675.laz']
# Saved 52200 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357651_45454.las
# Loaded 43 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357657_45453.las
# Found 87 nearby points in tile ['tile_x_395875_y_6784675.laz', 'tile_x_395875_y_6784725.laz', 'tile_x_395925_y_6784675.laz', 'tile_x_395825_y_6784675.laz']
# Saved 243144 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357657_45453.las
# Loaded 56 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362357663_45455.las
# Found 109 nearby points in tile ['tile_x_395925_y_6784775.laz', 'tile_x_395925_y_6784725.laz', 'tile_x_395975_y_6784775.laz', 'tile_x_395975_y_6784725.laz']
# Saved 156834 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362357663_45455.las
# Loaded 1 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358041_45472.las
# Found 2 nearby points in tile ['tile_x_395975_y_6783925.laz', 'tile_x_395975_y_6783975.laz', 'tile_x_396025_y_6783925.laz', 'tile_x_395925_y_6783925.laz']
# Saved 17343 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358041_45472.las
# Loaded 19 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358053_45471.las
# Found 33 nearby points in tile ['tile_x_395975_y_6783925.laz', 'tile_x_395975_y_6783975.laz', 'tile_x_396025_y_6783925.laz', 'tile_x_395925_y_6783925.laz']
# Saved 103784 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358053_45471.las
# Loaded 25 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358065_45470.las
# Found 53 nearby points in tile ['tile_x_395975_y_6783825.laz', 'tile_x_396025_y_6783825.laz', 'tile_x_395975_y_6783775.laz', 'tile_x_395975_y_6783875.laz']
# Saved 107167 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358065_45470.las
# Loaded 91 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358071_45469.las
# Found 155 nearby points in tile ['tile_x_395625_y_6783775.laz', 'tile_x_395625_y_6783725.laz', 'tile_x_395575_y_6783775.laz', 'tile_x_395575_y_6783725.laz']
# Saved 493534 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358071_45469.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358125_45492.las
# Found 4 nearby points in tile ['tile_x_396375_y_6783975.laz', 'tile_x_396325_y_6783975.laz', 'tile_x_396375_y_6784025.laz', 'tile_x_396325_y_6784025.laz']
# Saved 30975 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358125_45492.las
# Loaded 71 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358149_1274.las
# Found 118 nearby points in tile ['tile_x_398375_y_6784475.laz', 'tile_x_398375_y_6784525.laz', 'tile_x_398325_y_6784475.laz', 'tile_x_398325_y_6784525.laz']
# Saved 460036 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358149_1274.las
# Loaded 24 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358167_45477.las
# Found 44 nearby points in tile ['tile_x_397775_y_6784125.laz', 'tile_x_397725_y_6784125.laz', 'tile_x_397775_y_6784175.laz', 'tile_x_397775_y_6784075.laz']
# Saved 127316 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358167_45477.las
# Loaded 36 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358179_992.las
# Found 64 nearby points in tile ['tile_x_397975_y_6784025.laz', 'tile_x_398025_y_6784025.laz', 'tile_x_397975_y_6784075.laz', 'tile_x_398025_y_6784075.laz']
# Saved 131146 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358179_992.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358209_45491.las
# Found 22 nearby points in tile ['tile_x_396425_y_6783925.laz', 'tile_x_396375_y_6783925.laz', 'tile_x_396425_y_6783975.laz', 'tile_x_396375_y_6783975.laz']
# Saved 85845 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358209_45491.las
# Loaded 37 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358215_45489.las
# Found 66 nearby points in tile ['tile_x_396225_y_6783875.laz', 'tile_x_396275_y_6783875.laz', 'tile_x_396225_y_6783925.laz', 'tile_x_396225_y_6783825.laz']
# Saved 270953 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358215_45489.las
# Loaded 48 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358233_45484.las
# Found 99 nearby points in tile ['tile_x_396375_y_6783975.laz', 'tile_x_396325_y_6783975.laz', 'tile_x_396375_y_6784025.laz', 'tile_x_396325_y_6784025.laz']
# Saved 294315 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358233_45484.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358251_45486.las
# Found 45 nearby points in tile ['tile_x_396175_y_6784175.laz', 'tile_x_396125_y_6784175.laz', 'tile_x_396175_y_6784225.laz', 'tile_x_396175_y_6784125.laz']
# Saved 184954 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358251_45486.las
# Loaded 58 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358263_19148.las
# Found 114 nearby points in tile ['tile_x_397875_y_6783775.laz', 'tile_x_397875_y_6783825.laz', 'tile_x_397825_y_6783775.laz', 'tile_x_397825_y_6783825.laz']
# Saved 238459 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358263_19148.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358269_45479.las
# Found 24 nearby points in tile ['tile_x_397975_y_6783525.laz', 'tile_x_397925_y_6783525.laz', 'tile_x_397975_y_6783575.laz', 'tile_x_397925_y_6783575.laz']
# Saved 88026 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358269_45479.las
# Loaded 28 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358275_45490.las
# Found 57 nearby points in tile ['tile_x_396525_y_6783925.laz', 'tile_x_396525_y_6783875.laz', 'tile_x_396575_y_6783925.laz', 'tile_x_396575_y_6783875.laz']
# Saved 112056 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358275_45490.las
# Loaded 180 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358281_45476.las
# Found 358 nearby points in tile ['tile_x_397375_y_6783825.laz', 'tile_x_397425_y_6783825.laz', 'tile_x_397375_y_6783775.laz', 'tile_x_397425_y_6783775.laz']
# Saved 944953 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358281_45476.las
# Loaded 64 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358287_45483.las
# Found 136 nearby points in tile ['tile_x_396775_y_6784125.laz', 'tile_x_396775_y_6784075.laz', 'tile_x_396725_y_6784125.laz', 'tile_x_396725_y_6784075.laz']
# Saved 280627 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358287_45483.las
# Loaded 57 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358299_45465.las
# Found 108 nearby points in tile ['tile_x_395875_y_6784075.laz', 'tile_x_395875_y_6784025.laz', 'tile_x_395925_y_6784075.laz', 'tile_x_395925_y_6784025.laz']
# Saved 239614 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358299_45465.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358305_45466.las
# Found 23 nearby points in tile ['tile_x_395825_y_6784025.laz', 'tile_x_395875_y_6784025.laz', 'tile_x_395825_y_6783975.laz', 'tile_x_395875_y_6783975.laz']
# Saved 62111 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358305_45466.las
# Loaded 47 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358317_45485.las
# Found 98 nearby points in tile ['tile_x_396175_y_6784025.laz', 'tile_x_396125_y_6784025.laz', 'tile_x_396175_y_6784075.laz', 'tile_x_396125_y_6784075.laz']
# Saved 169221 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362358317_45485.las
# Loaded 129 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362358347_45435.las
# ...
# Found 229 nearby points in tile ['tile_x_400425_y_6786425.laz', 'tile_x_400425_y_6786475.laz', 'tile_x_400375_y_6786425.laz', 'tile_x_400375_y_6786475.laz']
# Saved 608839 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408363_9868.las
# Loaded 91 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408369_9854.las
# Found 115 nearby points in tile ['tile_x_400525_y_6786075.laz', 'tile_x_400525_y_6786025.laz', 'tile_x_400525_y_6786125.laz', 'tile_x_400525_y_6785975.laz']
# Saved 360449 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408369_9854.las
# Loaded 125 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408465_9609.las
# Found 231 nearby points in tile ['tile_x_400275_y_6787925.laz', 'tile_x_400225_y_6787925.laz', 'tile_x_400275_y_6787875.laz', 'tile_x_400225_y_6787875.laz']
# Saved 760651 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408465_9609.las
# Loaded 173 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408501_19086.las
# Found 323 nearby points in tile ['tile_x_399875_y_6784575.laz', 'tile_x_399925_y_6784575.laz', 'tile_x_399875_y_6784525.laz', 'tile_x_399925_y_6784525.laz']
# Saved 899897 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408501_19086.las
# Loaded 11 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408519_9788.las
# Found 16 nearby points in tile ['tile_x_399175_y_6787525.laz', 'tile_x_399175_y_6787575.laz', 'tile_x_399125_y_6787525.laz', 'tile_x_399125_y_6787575.laz']
# Saved 94945 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408519_9788.las
# Loaded 185 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408609_1273.las
# Found 335 nearby points in tile ['tile_x_399175_y_6784975.laz', 'tile_x_399175_y_6785025.laz', 'tile_x_399125_y_6784975.laz', 'tile_x_399125_y_6785025.laz']
# Saved 928550 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408609_1273.las
# Loaded 56 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408627_19112.las
# Found 113 nearby points in tile ['tile_x_399475_y_6785225.laz', 'tile_x_399475_y_6785175.laz', 'tile_x_399425_y_6785225.laz', 'tile_x_399425_y_6785175.laz']
# Saved 262939 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408627_19112.las
# Loaded 33 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408633_19132.las
# Found 72 nearby points in tile ['tile_x_399275_y_6785425.laz', 'tile_x_399275_y_6785375.laz', 'tile_x_399325_y_6785425.laz', 'tile_x_399325_y_6785375.laz']
# Saved 191417 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408633_19132.las
# Loaded 98 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408639_19087.las
# Found 205 nearby points in tile ['tile_x_399525_y_6785675.laz', 'tile_x_399525_y_6785625.laz', 'tile_x_399575_y_6785675.laz', 'tile_x_399575_y_6785625.laz']
# Saved 595691 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408639_19087.las
# Loaded 95 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408657_19106.las
# Found 223 nearby points in tile ['tile_x_400025_y_6785675.laz', 'tile_x_399975_y_6785675.laz', 'tile_x_400025_y_6785625.laz', 'tile_x_399975_y_6785625.laz']
# Saved 658658 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408657_19106.las
# Loaded 14 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408663_19115.las
# Found 39 nearby points in tile ['tile_x_399475_y_6785125.laz', 'tile_x_399425_y_6785125.laz', 'tile_x_399475_y_6785175.laz', 'tile_x_399425_y_6785175.laz']
# Saved 77853 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408663_19115.las
# Loaded 71 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408669_19133.las
# Found 126 nearby points in tile ['tile_x_399425_y_6785125.laz', 'tile_x_399475_y_6785125.laz', 'tile_x_399425_y_6785075.laz', 'tile_x_399425_y_6785175.laz']
# Saved 370342 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408669_19133.las
# Loaded 27 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408675_19114.las
# Found 38 nearby points in tile ['tile_x_399575_y_6785125.laz', 'tile_x_399575_y_6785075.laz', 'tile_x_399525_y_6785125.laz', 'tile_x_399625_y_6785125.laz']
# Saved 140933 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408675_19114.las
# Loaded 30 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408801_19122.las
# Found 49 nearby points in tile ['tile_x_398525_y_6784875.laz', 'tile_x_398575_y_6784875.laz', 'tile_x_398525_y_6784825.laz', 'tile_x_398575_y_6784825.laz']
# Saved 170648 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408801_19122.las
# Loaded 172 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408903_9825.las
# Found 343 nearby points in tile ['tile_x_399875_y_6785975.laz', 'tile_x_399925_y_6785975.laz', 'tile_x_399875_y_6786025.laz', 'tile_x_399875_y_6785925.laz']
# Saved 1170229 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408903_9825.las
# Loaded 88 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408939_9649.las
# Found 155 nearby points in tile ['tile_x_399725_y_6787625.laz', 'tile_x_399725_y_6787575.laz', 'tile_x_399675_y_6787625.laz', 'tile_x_399675_y_6787575.laz']
# Saved 589328 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408939_9649.las
# Loaded 74 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408945_9652.las
# Found 136 nearby points in tile ['tile_x_399775_y_6787975.laz', 'tile_x_399825_y_6787975.laz', 'tile_x_399775_y_6787925.laz', 'tile_x_399825_y_6787925.laz']
# Saved 501064 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408945_9652.las
# Loaded 87 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408951_683.las
# Found 167 nearby points in tile ['tile_x_400175_y_6787275.laz', 'tile_x_400175_y_6787225.laz', 'tile_x_400225_y_6787275.laz', 'tile_x_400225_y_6787225.laz']
# Saved 461650 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408951_683.las
# Loaded 158 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408957_682.las
# Found 293 nearby points in tile ['tile_x_400275_y_6787925.laz', 'tile_x_400225_y_6787925.laz', 'tile_x_400275_y_6787875.laz', 'tile_x_400225_y_6787875.laz']
# Saved 749758 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408957_682.las
# Loaded 105 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408975_9871.las
# Found 42 nearby points in tile ['tile_x_400525_y_6786775.laz', 'tile_x_400525_y_6786825.laz', 'tile_x_400525_y_6786725.laz', 'tile_x_400525_y_6786875.laz']
# Saved 102104 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408975_9871.las
# Loaded 32 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362408987_19092.las
# Found 70 nearby points in tile ['tile_x_399075_y_6785825.laz', 'tile_x_399075_y_6785775.laz', 'tile_x_399125_y_6785825.laz', 'tile_x_399125_y_6785775.laz']
# Saved 195179 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362408987_19092.las
# Loaded 35 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409005_9836.las
# Found 68 nearby points in tile ['tile_x_399075_y_6786175.laz', 'tile_x_399075_y_6786125.laz', 'tile_x_399125_y_6786175.laz', 'tile_x_399025_y_6786175.laz']
# Saved 292578 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409005_9836.las
# Loaded 43 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409011_9832.las
# Found 75 nearby points in tile ['tile_x_399325_y_6786325.laz', 'tile_x_399325_y_6786375.laz', 'tile_x_399275_y_6786325.laz', 'tile_x_399275_y_6786375.laz']
# Saved 283549 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409011_9832.las
# Loaded 7 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409017_9831.las
# Found 10 nearby points in tile ['tile_x_399325_y_6786375.laz', 'tile_x_399325_y_6786425.laz', 'tile_x_399275_y_6786375.laz', 'tile_x_399375_y_6786375.laz']
# Saved 29344 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409017_9831.las
# Loaded 63 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409083_19170.las
# Found 118 nearby points in tile ['tile_x_399075_y_6783875.laz', 'tile_x_399075_y_6783925.laz', 'tile_x_399125_y_6783875.laz', 'tile_x_399125_y_6783925.laz']
# Saved 442429 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409083_19170.las
# Loaded 225 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409089_19154.las
# Found 198 nearby points in tile ['tile_x_399225_y_6783525.laz', 'tile_x_399175_y_6783525.laz', 'tile_x_399275_y_6783525.laz', 'tile_x_399125_y_6783525.laz']
# Saved 873681 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409089_19154.las
# Loaded 60 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409095_19171.las
# Found 130 nearby points in tile ['tile_x_399275_y_6784125.laz', 'tile_x_399225_y_6784125.laz', 'tile_x_399275_y_6784075.laz', 'tile_x_399225_y_6784075.laz']
# Saved 447126 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409095_19171.las
# Loaded 150 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409197_19084.las
# Found 135 nearby points in tile ['tile_x_400525_y_6785425.laz', 'tile_x_400525_y_6785475.laz', 'tile_x_400525_y_6785375.laz', 'tile_x_400525_y_6785525.laz']
# Saved 372611 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409197_19084.las
# Loaded 73 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362409209_19123.las
# Found 142 nearby points in tile ['tile_x_398575_y_6784975.laz', 'tile_x_398575_y_6785025.laz', 'tile_x_398525_y_6784975.laz', 'tile_x_398525_y_6785025.laz']
# Saved 460960 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362409209_19123.las
# Loaded 12 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362413168_9603.las
# Found 24 nearby points in tile ['tile_x_399825_y_6788275.laz', 'tile_x_399825_y_6788325.laz', 'tile_x_399775_y_6788275.laz', 'tile_x_399775_y_6788325.laz']
# Saved 106743 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362413168_9603.las
# Loaded 2 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362413174_9604.las
# Found 3 nearby points in tile ['tile_x_399825_y_6788275.laz', 'tile_x_399825_y_6788325.laz', 'tile_x_399775_y_6788275.laz', 'tile_x_399875_y_6788275.laz']
# Saved 34761 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362413174_9604.las
# Loaded 184 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362413288_9262.las
# Found 333 nearby points in tile ['tile_x_399325_y_6788225.laz', 'tile_x_399375_y_6788225.laz', 'tile_x_399325_y_6788275.laz', 'tile_x_399375_y_6788275.laz']
# Saved 1157011 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362413288_9262.las
# Loaded 103 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362422281_9590.las
# Found 103 nearby points in tile ['tile_x_400125_y_6788525.laz', 'tile_x_400175_y_6788525.laz', 'tile_x_400075_y_6788525.laz', 'tile_x_400225_y_6788525.laz']
# Saved 331549 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362422281_9590.las
# Loaded 182 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362422305_9576.las
# Found 140 nearby points in tile ['tile_x_399275_y_6788525.laz', 'tile_x_399325_y_6788525.laz', 'tile_x_399225_y_6788525.laz', 'tile_x_399375_y_6788525.laz']
# Saved 313822 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362422305_9576.las
# Loaded 92 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362422634_9575.las
# Found 178 nearby points in tile ['tile_x_399775_y_6788325.laz', 'tile_x_399775_y_6788375.laz', 'tile_x_399825_y_6788325.laz', 'tile_x_399825_y_6788375.laz']
# Saved 409057 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362422634_9575.las
# Loaded 52 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362471542_45456.las
# Found 97 nearby points in tile ['tile_x_395675_y_6784275.laz', 'tile_x_395725_y_6784275.laz', 'tile_x_395675_y_6784325.laz', 'tile_x_395725_y_6784325.laz']
# Saved 332760 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362471542_45456.las
# Loaded 19 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\362473668_9795.las
# Found 36 nearby points in tile ['tile_x_399025_y_6787075.laz', 'tile_x_399025_y_6787025.laz', 'tile_x_398975_y_6787075.laz', 'tile_x_398975_y_6787025.laz']
# Saved 76501 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\362473668_9795.las
# Loaded 16 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\364413600_19167.las
# Found 44 nearby points in tile ['tile_x_399625_y_6783625.laz', 'tile_x_399625_y_6783575.laz', 'tile_x_399575_y_6783625.laz', 'tile_x_399575_y_6783575.laz']
# Saved 90991 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364413600_19167.las
# Loaded 13 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\364413952_19109.las
# Found 27 nearby points in tile ['tile_x_399575_y_6785725.laz', 'tile_x_399575_y_6785675.laz', 'tile_x_399525_y_6785725.laz', 'tile_x_399525_y_6785675.laz']
# Saved 71703 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\364413952_19109.las
# Loaded 17 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\461794926_19149.las
# Found 26 nearby points in tile ['tile_x_398575_y_6783525.laz', 'tile_x_398525_y_6783525.laz', 'tile_x_398575_y_6783575.laz', 'tile_x_398525_y_6783575.laz']
# Saved 52738 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461794926_19149.las
# Loaded 18 trajectory points from C:\Users\telukkari\Documents\Python\time_series_analysis\data\road_vecs_las_Padasjoki_20231023\461795483_19150.las
# Found 31 nearby points in tile ['tile_x_398025_y_6783575.laz', 'tile_x_398025_y_6783525.laz', 'tile_x_398075_y_6783575.laz', 'tile_x_398075_y_6783525.laz']
# Saved 116191 unique points to E:\ALS_DATA\NLS_20p_EVO_road_patches\461795483_19150.las
